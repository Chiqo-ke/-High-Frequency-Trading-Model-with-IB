# %% [markdown]
# # TradingView Data Fetcher
#
# This notebook connects to TradingView and fetches EURUSD data using the following steps:
# 1. Initialize TradingView connection
# 2. Fetch hourly data
# 3. Save data to CSV

# %%
from tvDatafeed import TvDatafeed, Interval

username = 'Chiqo-dev'
password = 'ChiqoMehum8844'
tv = TvDatafeed(username, password)
# Out:
# ERROR:tvDatafeed.main:error while signin
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
H1_data = tv.get_hist(symbol='EURUSD',exchange='OANDA',interval=Interval.in_1_minute,n_bars=10)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 H1_data = tv.get_hist(symbol='EURUSD',exchange='OANDA',interval=Interval.in_1_minute,n_bars=10)
#
# File ~/Documents/AI/High-Frequency-Trading-Model-with-IB/.venv/lib/python3.12/site-packages/tvDatafeed/main.py:216, in TvDatafeed.get_hist(self, symbol, exchange, interval, n_bars, fut_contract, extended_session)
#     210 symbol = self.__format_symbol(
#     211     symbol=symbol, exchange=exchange, contract=fut_contract
#     212 )
#     214 interval = interval.value
# --> 216 self.__create_connection()
#     218 self.__send_message("set_auth_token", [self.token])
#     219 self.__send_message("chart_create_session", [self.chart_session, ""])
#
# File ~/Documents/AI/High-Frequency-Trading-Model-with-IB/.venv/lib/python3.12/site-packages/tvDatafeed/main.py:86, in TvDatafeed.__create_connection(self)
# ...
